// %%
import (
    "fmt"
    "strconv"
    "strings"
)

func convert(numbers string) (result []int) {
    for _, e := range strings.Split(numbers, " ") {
        if n, err := strconv.Atoi(e); err == nil {
            result = append(result, n)
        } else {
            panic(err)
        }
    }
    return
}

func zip(a, b []int) ([]intTuple, error) {

    if len(a) != len(b) {
        return nil, fmt.Errorf("zip: arguments must be of same length")
    }

    r := make([]intTuple, len(a), len(a))

    for i, e := range a {
        r[i] = intTuple{e, b[i]}
    }

    return r, nil
}


func parseMap(lines string) {
    
}

type arange struct {
    start int
    end int
}

func (a *arange) has(i int) bool {
    return i >= a.start && i < a.end
}

func main() {
    var input = `seeds: 79 14 55 13

seed-to-soil map:
50 98 2
52 50 48

soil-to-fertilizer map:
0 15 37
37 52 2
39 0 15

fertilizer-to-water map:
49 53 8
0 11 42
42 0 7
57 7 4

water-to-light map:
88 18 7
18 25 70

light-to-temperature map:
45 77 23
81 45 19
68 64 13

temperature-to-humidity map:
0 69 1
1 0 69

humidity-to-location map:
60 56 37
56 93 4`;
    
    var parts = strings.Split(input, "\n\n");
    var seed_str, maps = parts[0], parts[1:]
    seed_str = seed_str[7:]
    
    var seeds = convert(seed_str)
    
    fmt.Println(seeds)
    fmt.Println(maps)
    
    var r = arange{0,5}
    fmt.Println(r.has(4))
    
    /*
    for _, line := range strings.Split(input, "\n\n") {
        fmt.Println(line)
    }*/
}
// Out:
// [79 14 55 13]
// [seed-to-soil map:
// 50 98 2
// 52 50 48 soil-to-fertilizer map:
// 0 15 37
// 37 52 2
// 39 0 15 fertilizer-to-water map:
// 49 53 8
// 0 11 42
// 42 0 7
// 57 7 4 water-to-light map:
// 88 18 7
// 18 25 70 light-to-temperature map:
// 45 77 23
// 81 45 19
// 68 64 13 temperature-to-humidity map:
// 0 69 1
// 1 0 69 humidity-to-location map:
// 60 56 37
// 56 93 4]
// true
